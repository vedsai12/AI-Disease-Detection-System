# %% [markdown]
# <a href="https://colab.research.google.com/github/vedsai12/AI-Disease-Detection-System/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install flask flask-ngrok joblib scikit-learn pandas numpy

# %%
# !python app.py
# Out:
# python3: can't open file '/content/app.py': [Errno 2] No such file or directory
